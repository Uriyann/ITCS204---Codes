# %%
# Dictionary 1

Nobility_Ranks = {
    1: "Emperor",
    2: "King, Queen",
    3: "Archduke",
    4: "Grand Duke",
    5: "Duke, Duchess",
    6: "Marquess, Marchioness",
    7: "Earl, Count, Countess",
    8: "Viscount, Viscountess",
    9: "Baron, Baroness",
    10: "Lord, Lady",
    11: "Baronet",
    12: "Knight, Dame",
    13: "Squire",
    14: "Esquire",
    15: "Chieftain",
    16: "Petty Noble",
    17: "Yeoman",
    18: "Gentleman, Gentlewoman",
    19: "Commoner",
    20: "Peasant"
}

Nobility_Ranks[20] = "Serf"
Nobility_Ranks[21] = "Slave"
Nobility_Ranks[0] = "Overlord"

for rank in Nobility_Ranks:
    print(f"Rank {rank}: {Nobility_Ranks[rank]}")

print(f"\n\nAnomaly Rank: {Nobility_Ranks[0]}")
print(f"Lowest Rank: {Nobility_Ranks[21]}\n\n")
# Out:
# Rank 1: Emperor
# Rank 2: King, Queen
# Rank 3: Archduke
# Rank 4: Grand Duke
# Rank 5: Duke, Duchess
# Rank 6: Marquess, Marchioness
# Rank 7: Earl, Count, Countess
# Rank 8: Viscount, Viscountess
# Rank 9: Baron, Baroness
# Rank 10: Lord, Lady
# Rank 11: Baronet
# Rank 12: Knight, Dame
# Rank 13: Squire
# Rank 14: Esquire
# Rank 15: Chieftain
# Rank 16: Petty Noble
# Rank 17: Yeoman
# Rank 18: Gentleman, Gentlewoman
# Rank 19: Commoner
# Rank 20: Serf
# Rank 21: Slave
# Rank 0: Overlord
#
#
# Anomaly Rank: Overlord
# Lowest Rank: Slave
#
#
# Rank 1: Zeus
# Rank 2: Hera
# Rank 3: Poseidon
# Rank 4: Demeter
# Rank 5: Athena
# Rank 6: Apollo
# Rank 7: Artemis
# Rank 8: Ares
# Rank 9: Aphrodite
# Rank 10: Hephaestus
# Rank 11: Hermes
# Rank 12: Hestia
# Rank 13: Dionysus
# Rank 14: Hades
# Rank 15: Persephone
# Rank 16: Hecate
# Rank 17: Helios
# Rank 18: Selene
# Rank 19: Eros
# Rank 20: Nyx
# Rank 21: Gaia
# Rank 22: Uranus
# Rank 23: Cronus
# Rank 24: Rhea
# Rank 25: Thanatos
# ...

# %%
# Dictionary 2

Greek_Gods_Ranks = {
    1: "Zeus",
    2: "Hera",
    3: "Poseidon",
    4: "Demeter",
    5: "Athena",
    6: "Apollo",
    7: "Artemis",
    8: "Ares",
    9: "Aphrodite",
    10: "Hephaestus",
    11: "Hermes",
    12: "Hestia",
    13: "Dionysus",
    14: "Hades",
    15: "Persephone",
    16: "Hecate",
    17: "Helios",
    18: "Selene",
    19: "Eros",
    20: "Nyx",
    21: "Gaia",
    22: "Uranus",
    23: "Cronus",
    24: "Rhea",
    25: "Thanatos"
}

Greek_Gods_Ranks[26] = "Chaos"
Greek_Gods_Ranks[0] = "Primordial Void"

for rank in Greek_Gods_Ranks:
    print(f"Rank {rank}: {Greek_Gods_Ranks[rank]}")

print(f"\n\nAnomaly Rank: {Greek_Gods_Ranks[0]}")
print(f"King of Gods: {Greek_Gods_Ranks[1]}")
