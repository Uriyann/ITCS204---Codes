# %%
# List 1

My_Favorite_Anime = [
    "Reincarnated As A Sword",
    "Tonikaku Kawaii",
    "Black Bullet",
    "Josee to Tora to Sakana-tachi",
    "Why Raeliana Ended Up at the Duke's Mansion",
    "Food Wars S1-S5",
    "Sentai Daishikkaku",
    "Death March to the Parallel World Rhapsody",
    "Ancient Magus Bride",
    "Moriaty the Pariot",
    "Oshio to Tora",
    "To Every You I've Loved Before",
    "Seton Academy: Join the Pack!",
    "Trinity Seven",
    "The Pet Girl of Sakurasou",
    "Your Name",
    "Gamers",
    "Noblesse",
    "Mashle",
    "A Returner's Magic Should Be Special",
    "Engaged to the Unidentified",
    "Majo no Tabitabi",
    "Sasaki and Peeps",
    "High School dxd S1-S4",
    "Toradora"
]

My_Favorite_Anime.append("Bochi the Rock!")
My_Favorite_Anime.append("Call of the Night")

My_Favorite_Anime.remove("Oshio to Tora")
My_Favorite_Anime.remove("Trinity Seven")

My_Favorite_Anime.pop(5)
My_Favorite_Anime.pop(11)

for anime in My_Favorite_Anime:
    print(anime)

print(f"\n\nMy Favorite List: {My_Favorite_Anime[5:10]}")
print(f"\nMy Favorite List: {My_Favorite_Anime[16:25]}\n\n")
# Out:
# Reincarnated As A Sword
# Tonikaku Kawaii
# Black Bullet
# Josee to Tora to Sakana-tachi
# Why Raeliana Ended Up at the Duke's Mansion
# Sentai Daishikkaku
# Death March to the Parallel World Rhapsody
# Ancient Magus Bride
# Moriaty the Pariot
# To Every You I've Loved Before
# Seton Academy: Join the Pack!
# Your Name
# Gamers
# Noblesse
# Mashle
# A Returner's Magic Should Be Special
# Engaged to the Unidentified
# Majo no Tabitabi
# Sasaki and Peeps
# High School dxd S1-S4
# Toradora
# Bochi the Rock!
# Call of the Night
#
#
# My Favorite List: ['Sentai Daishikkaku', 'Death March to the Parallel World Rhapsody', 'Ancient Magus Bride', 'Moriaty the Pariot', "To Every You I've Loved Before"]
#
# My Favorite List: ['Engaged to the Unidentified', 'Majo no Tabitabi', 'Sasaki and Peeps', 'High School dxd S1-S4', 'Toradora', 'Bochi the Rock!', 'Call of the Night']

# %%
# List 2

Holo_Vtubers = [
    "Inugami Korone",
    "Usada Pekora",
    "Shiranui Flare",
    "Minato Aqua",
    "Houshou Marine",
    "Natsuiro Matsuri",
    "Yuzuki Choco",
    "Amane Kanata",
    "Murasaki Shion",
    "Ayunda Risu",
    "Moona Hoshinova",
    "Airani Iofifteen",
    "Gawr Gura",
    "Mori Calliope",
    "Takanashi Kiara",
    "Ninomae Ina'nis",
    "Watson Amelia",
    "IRyS",
    "Ceres Fauna",
    "Ouro Kronii"
]

Holo_Vtubers.append("Hakos Baelz")
Holo_Vtubers.append("Tsukumo Sana")

Holo_Vtubers.remove("Yuzuki Choco")
Holo_Vtubers.remove("Ceres Fauna")

Holo_Vtubers.pop(3)
Holo_Vtubers.pop(7)

for vtuber in Holo_Vtubers:
    print(vtuber)

print(f"\n\nHolo Vtubers List: {Holo_Vtubers[4:10]}")
print(f"Holo Vtubers List: {Holo_Vtubers[12:18]}")
